# %% [markdown]
# G1953496892-LPCLOUD
# - BROWSE https://lpdaac.earthdata.nasa.gov/lp-prod-public/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.jpg

# %%
right={'zone':'19', 'id':'G1953496892-LPCLOUD',
       'browse':'https://lpdaac.earthdata.nasa.gov/lp-prod-public/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.jpg'}

# %%
right
# Out:
# {'zone': '19',
#  'id': 'G1953496892-LPCLOUD',
#  'browse': 'https://lpdaac.earthdata.nasa.gov/lp-prod-public/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.jpg'}

# %% [markdown]
# G1951510836-LPCLOUD
# - BROWSE https://lpdaac.earthdata.nasa.gov/lp-prod-public/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.jpg

# %%
left={'zone':'18', 'id':'G1951510836-LPCLOUD',
       'browse':'https://lpdaac.earthdata.nasa.gov/lp-prod-public/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.jpg'}

# %%
left
# Out:
# {'zone': '18',
#  'id': 'G1951510836-LPCLOUD',
#  'browse': 'https://lpdaac.earthdata.nasa.gov/lp-prod-public/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.jpg'}

# %%
from IPython.display import Image

display(Image(left['browse']))

# %%
display(Image(right['browse']))

# %%
import urllib
import json
#def return_assets(id):
    
id=left['id']    
json_file = f'https://cmr.earthdata.nasa.gov/search/concepts/{id}.umm_json'
with urllib.request.urlopen(json_file) as url:
        my_meta = json.loads(url.read().decode())

# %%
my_meta
# Out:
# {'RelatedUrls': [{'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B07.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B07.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B09.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B09.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B08.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B08.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B03.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B03.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B02.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B02.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B01.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B01.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.SAA.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.SAA.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.Fmask.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.Fmask.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.SZA.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.SZA.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B06.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B06.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.VZA.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.VZA.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B11.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B11.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.VAA.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.VAA.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B8A.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B8A.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B12.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B12.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B10.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B10.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B05.tif',
#    'Type': 'GET DATA',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B05.tif'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.cmr.xml',
#    'Type': 'VIEW RELATED INFORMATION',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.cmr.xml'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/s3credentials',
#    'Type': 'VIEW RELATED INFORMATION',
#    'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access'},
#   {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-public/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.jpg',
#    'Type': 'GET RELATED VISUALIZATION',
#    'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.jpg'}],
#  'SpatialExtent': {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -71.06996661,
#          'Latitude': 44.99758761},
#         {'Longitude': -71.00067944, 'Latitude': 45.98354521},
#         {'Longitude': -72.41645116, 'Latitude': 46.02436508},
#         {'Longitude': -72.46129314, 'Latitude': 45.0370344},
#         {'Longitude': -71.06996661, 'Latitude': 44.99758761}]}}]}}},
#  'ProviderDates': [{'Date': '2020-10-11T13:54:29.434Z', 'Type': 'Insert'},
#   {'Date': '2020-10-11T13:54:29.434Z', 'Type': 'Update'}],
#  'AdditionalAttributes': [{'Name': 'PRODUCT_URI',
#    'Values': ['S2B_MSIL1C_20201009T154059_N0209_R011_T18TYR_20201009T190715.SAFE']},
#   {'Name': 'CLOUD_COVERAGE', 'Values': ['23']},
#   {'Name': 'MGRS_TILE_ID', 'Values': ['18TYR']},
#   {'Name': 'SPATIAL_COVERAGE', 'Values': ['99']},
#   {'Name': 'SPATIAL_RESOLUTION', 'Values': ['30']},
#   {'Name': 'HLS_PROCESSING_TIME', 'Values': ['2020-10-11T13:53:20Z']},
#   {'Name': 'SENSING_TIME', 'Values': ['2020-10-09T15:50:35.504361Z']},
#   {'Name': 'HORIZONTAL_CS_CODE', 'Values': ['EPSG:32618']},
#   {'Name': 'HORIZONTAL_CS_NAME', 'Values': ['WGS84 / UTM zone 18N']},
#   {'Name': 'ULX', 'Values': ['699960.0']},
#   {'Name': 'ULY', 'Values': ['5100000.0']},
#   {'Name': 'SPATIAL_RESAMPLING_ALG', 'Values': ['Area Weighted Average']},
#   {'Name': 'ADD_OFFSET', 'Values': ['0']},
#   {'Name': 'REF_SCALE_FACTOR', 'Values': ['0.0001']},
#   {'Name': 'FILLVALUE', 'Values': ['-9999']},
#   {'Name': 'QA_FILLVALUE', 'Values': ['255']},
#   {'Name': 'NCOLS', 'Values': ['3660']},
#   {'Name': 'NROWS', 'Values': ['3660']},
#   {'Name': 'MEAN_SUN_AZIMUTH_ANGLE', 'Values': ['166.44005583']},
#   {'Name': 'MEAN_SUN_ZENITH_ANGLE', 'Values': ['53.00586762']},
#   {'Name': 'MEAN_VIEW_AZIMUTH_ANGLE', 'Values': ['124.49498053']},
#   {'Name': 'MEAN_VIEW_ZENITH_ANGLE', 'Values': ['3.38189666']},
#   {'Name': 'NBAR_SOLAR_ZENITH', 'Values': ['53.44938017']},
#   {'Name': 'MSI_BAND_01_BANDPASS_ADJUSTMENT_SLOPE_AND_OFFSET',
#    'Values': ['0.9959', '-0.0002']},
#   {'Name': 'MSI_BAND_02_BANDPASS_ADJUSTMENT_SLOPE_AND_OFFSET',
#    'Values': ['0.9778', '-0.004']},
#   {'Name': 'MSI_BAND_03_BANDPASS_ADJUSTMENT_SLOPE_AND_OFFSET',
#    'Values': ['1.0075', '-0.0008']},
#   {'Name': 'MSI_BAND_04_BANDPASS_ADJUSTMENT_SLOPE_AND_OFFSET',
#    'Values': ['0.9761', '0.001']},
#   {'Name': 'MSI_BAND_11_BANDPASS_ADJUSTMENT_SLOPE_AND_OFFSET',
#    'Values': ['1.0', '-0.0003']},
#   {'Name': 'MSI_BAND_12_BANDPASS_ADJUSTMENT_SLOPE_AND_OFFSET',
#    'Values': ['0.9867', '0.0004']},
#   {'Name': 'MSI_BAND_8A_BANDPASS_ADJUSTMENT_SLOPE_AND_OFFSET',
#    'Values': ['0.9966', '0.0']},
#   {'Name': 'AROP_AVE_XSHIFT(METERS)', 'Values': ['0.0']},
#   {'Name': 'AROP_AVE_YSHIFT(METERS)', 'Values': ['0.0']},
#   {'Name': 'AROP_NCP', 'Values': ['0']},
#   {'Name': 'AROP_RMSE(METERS)', 'Values': ['0.0']},
#   {'Name': 'AROP_S2_REFIMG', 'Values': ['NONE']},
#   {'Name': 'ACCODE', 'Values': ['LaSRC']},
#   {'Name': 'PROCESSING_BASELINE', 'Values': ['02.09']},
#   {'Name': 'IDENTIFIER_PRODUCT_DOI', 'Values': ['10.5067/HLS/HLSS30.015']},
#   {'Name': 'IDENTIFIER_PRODUCT_DOI_AUTHORITY', 'Values': ['https://doi.org']}],
#  'CollectionReference': {'EntryTitle': 'HLS Sentinel-2 Multi-spectral Instrument Surface Reflectance Daily Global 30 m V1.5'},
#  'DataGranule': {'DayNightFlag': 'Day',
#   'Identifiers': [{'Identifier': 'HLS.S30.T18TYR.2020283T154059',
#     'IdentifierType': 'ProducerGranuleId'}],
#   'ProductionDateTime': '2020-10-11T13:53:20.000Z',
#   'ArchiveAndDistributionInformation': [{'Name': 'Not provided',
#     'Size': 227223.0,
#     'SizeUnit': 'MB'}]},
#  'Platforms': [{'ShortName': 'Sentinel-2B',
#    'Instruments': [{'ShortName': 'Sentinel-2 MSI'}]}],
#  'TemporalExtent': {'RangeDateTime': {'BeginningDateTime': '2020-10-09T15:50:35.504Z',
#    'EndingDateTime': '2020-10-09T15:50:35.504Z'}},
#  'GranuleUR': 'HLS.S30.T18TYR.2020283T154059.v1.5',
#  'MetadataSpecification': {'URL': 'https://cdn.earthdata.nasa.gov/umm/granule/v1.6.1',
#   'Name': 'UMM-G',
#   'Version': '1.6.1'}}

# %% [markdown]
# ![limg](https://lpdaac.usgs.gov/media/images/HLS_Processing.width-800.jpg)

# %% [markdown]
# ```
# band02 	B02 	2 	2 	0.45 – 0.51 	Blue
# band03 	B03 	3 	3 	0.53 – 0.59 	Green
# band04 	B04 	4 	4 	0.64 – 0.67 	Red
# ```

# %%
my_meta["RelatedUrls"]
# Out:
# [{'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B07.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B07.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B09.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B09.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B08.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B08.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B03.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B03.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B02.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B02.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B01.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B01.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.SAA.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.SAA.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.Fmask.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.Fmask.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.SZA.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.SZA.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B06.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B06.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.VZA.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.VZA.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B11.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B11.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.VAA.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.VAA.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B8A.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B8A.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B12.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B12.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B10.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B10.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B05.tif',
#   'Type': 'GET DATA',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.B05.tif'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.cmr.xml',
#   'Type': 'VIEW RELATED INFORMATION',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.cmr.xml'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/s3credentials',
#   'Type': 'VIEW RELATED INFORMATION',
#   'Description': 'api endpoint to retrieve temporary credentials valid for same-region direct s3 access'},
#  {'URL': 'https://lpdaac.earthdata.nasa.gov/lp-prod-public/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.jpg',
#   'Type': 'GET RELATED VISUALIZATION',
#   'Description': 'Download HLS.S30.T18TYR.2020283T154059.v1.5.jpg'}]

# %%
url_list = []
for ref in my_meta["RelatedUrls"]:
    print(ref['URL'])
    url_list.append(ref['URL'])
# Out:
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B07.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B09.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B08.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B03.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B02.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B01.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.SAA.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.Fmask.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.SZA.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B06.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.VZA.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B11.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.VAA.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B8A.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B12.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B10.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B05.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.cmr.xml
# https://lpdaac.earthdata.nasa.gov/s3credentials
# https://lpdaac.earthdata.nasa.gov/lp-prod-public/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.jpg

# %%
def return_band_url(band_name, url_list):
    for ref in url_list:
        if band_name in ref:
            return(ref)

# %%
band_name = 'B04'
red = return_band_url(band_name, url_list)

# %%
#! mkdir -p ~/hls

# %%
red
# Out:
# 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif'

# %%
! pip install --user wget
# Out:
# Requirement already satisfied: wget in /home/jovyan/.local/lib/python3.7/site-packages (3.2)

# %%
import sys  
sys.path.insert(0, '.')
from hls_functions import urs_authenticate

urs_authenticate()

# %% [markdown]
# # next cell fails with unauthorized huh?

# %%
# import wget
# import os

# home = os.getenv("HOME")

# output_directory = home + '/hls'
# filename = wget.download(red, out=output_directory)
# filename

# %%
#! wget https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif

# %%
#! mv HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif ~/hls

# %%
#os.system('wget https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif')

# %%
#!ls

# %%
import urllib
import json
def return_assets(id):
    
    json_file = f'https://cmr.earthdata.nasa.gov/search/concepts/{id}.umm_json'
    with urllib.request.urlopen(json_file) as url:
        my_meta = json.loads(url.read().decode())
    url_list = []
    for ref in my_meta["RelatedUrls"]:
        print(ref['URL'])
        url_list.append(ref['URL'])
    return(url_list)

# %%
assets = return_assets(id)

red = return_band_url(band_name, assets)

red
# Out:
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B07.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B09.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B08.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B03.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B02.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B01.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.SAA.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.Fmask.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.SZA.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B06.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.VZA.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B11.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.VAA.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B8A.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B12.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B10.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B05.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.cmr.xml
# https://lpdaac.earthdata.nasa.gov/s3credentials
# https://lpdaac.earthdata.nasa.gov/lp-prod-public/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.jpg
# 'https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif'

# %%
import os
def wget_fetch(bref_url):
    home=os.getenv('HOME')
    filename = bref_url.split('/')[-1]
    cmd = f'wget {bref_url} -O {home}/hls/{filename}'
    print(cmd)
    os.system(cmd)

# %%
bands=['B04', 'B03', 'B02']

for band in bands:
    bref = return_band_url(band, assets)
    print(bref)
    wget_fetch(bref)
# Out:
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif
# wget https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif -O /home/jovyan/hls/HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B03.tif
# wget https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B03.tif -O /home/jovyan/hls/HLS.S30.T18TYR.2020283T154059.v1.5.B03.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B02.tif
# wget https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T18TYR.2020283T154059.v1.5.B02.tif -O /home/jovyan/hls/HLS.S30.T18TYR.2020283T154059.v1.5.B02.tif

# %%
assets = return_assets(right['id'])
# Out:
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.SAA.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B08.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B11.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B04.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.SZA.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B8A.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.VZA.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.VAA.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B02.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B03.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B10.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B01.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B12.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B09.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B07.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.Fmask.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B05.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B06.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.cmr.xml
# https://lpdaac.earthdata.nasa.gov/s3credentials
# https://lpdaac.earthdata.nasa.gov/lp-prod-public/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.jpg

# %%
bands=['B04', 'B03', 'B02']

for band in bands:
    bref = return_band_url(band, assets)
    print(bref)
    wget_fetch(bref)
# Out:
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B04.tif
# wget https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B04.tif -O /home/jovyan/hls/HLS.S30.T19TCL.2020288T154231.v1.5.B04.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B03.tif
# wget https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B03.tif -O /home/jovyan/hls/HLS.S30.T19TCL.2020288T154231.v1.5.B03.tif
# https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B02.tif
# wget https://lpdaac.earthdata.nasa.gov/lp-prod-protected/HLSS30.015/HLS.S30.T19TCL.2020288T154231.v1.5.B02.tif -O /home/jovyan/hls/HLS.S30.T19TCL.2020288T154231.v1.5.B02.tif

# %%
! ls ~/hls/
# Out:
# HLS.S30.T18TYR.2020283T154059.v1.5.B02.tif
# HLS.S30.T18TYR.2020283T154059.v1.5.B03.tif
# HLS.S30.T18TYR.2020283T154059.v1.5.B04.tif
# HLS.S30.T19TCL.2020288T154231.v1.5.B02.tif
# HLS.S30.T19TCL.2020288T154231.v1.5.B03.tif
# HLS.S30.T19TCL.2020288T154231.v1.5.B04.tif

# %%
#!ls

# %%
#! rm G*umm*

# %%
#!ls

# %%
#! rm H*.tif*

# %%
#!ls
